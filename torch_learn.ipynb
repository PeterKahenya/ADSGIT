# %% [markdown]
# <a href="https://colab.research.google.com/github/PeterKahenya/ADSGIT/blob/main/torch_learn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
